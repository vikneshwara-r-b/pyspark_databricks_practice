# %% [markdown]
# #### We are starting Pyspark
#
# **Keyboard shortcuts - Mac**
# - Command + Enter = Execute the current cell
# - Shift + Enter =  Execute the current cell and create a new cell

# %% [markdown]
# #### CSV file upload
# - Create a new managed volume with name-"pyspark_lab_1_csv" by choosing workspace catalog and default schema
# ![Screenshot 2026-02-24 at 6.58.43 AM.png](./Screenshot 2026-02-24 at 6.58.43 AM.png "Screenshot 2026-02-24 at 6.58.43 AM.png")
# - Upload file - BigMart Sales.csv to newly created volume in Unity Catalog

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.format("csv") \
    .option("inferSchema", True) \
    .option("header", True) \
    .load("/Volumes/workspace/default/pyspark_lab_1_csv/BigMart Sales.csv")

# %%
df.display()

# %%
df.printSchema()

# %%
df.createOrReplaceTempView("TEST_TABLE")

# %%
# %sql
desc TEST_TABLE
